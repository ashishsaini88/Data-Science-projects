# %%
import pandas as pd

# %%
d =pd.read_csv(r"C:\Users\KOIN\Downloads\pornstars_0.csv")
d.head()
# Out:
#    Unnamed: 0              0                                               1  \
# 0           0   Lana Rhoades   https://www.pornhub.com/pornstar/lana-rhoades
# 1           1   Angela White   https://www.pornhub.com/pornstar/angela-white
# 2           2      Eva Elfie      https://www.pornhub.com/pornstar/eva-elfie
# 3           3  Abella Danger  https://www.pornhub.com/pornstar/abella-danger
# 4           4     Alex Adams     https://www.pornhub.com/pornstar/alex-adams
#
#    2     3           4                                                  5  \
# 0  2   407  1800000000  https://ei.phncdn.com/pics/users/318/887/681/a...
# 1  3   851  1200000000  https://ei.phncdn.com/(m=eQJ6GCjadOf)(mh=cJBLt...
# 2  4   193  1000000000  https://ei.phncdn.com/pics/users/683/394/291/a...
# 3  5  1085  1900000000  https://ei.phncdn.com/pics/users/730/712/871/a...
# 4  7   416  2800000000  https://ei.phncdn.com/pics/users/372/679/361/a...
#
# ...

# %%
d
# Out:
#     Unnamed: 0                    0  \
# 0            0         Lana Rhoades
# 1            1         Angela White
# 2            2            Eva Elfie
# 3            3        Abella Danger
# 4            4           Alex Adams
# 5            5           Riley Reid
# 6            6          Mia Malkova
# 7            7         Violet Myers
# 8            8          Johnny Sins
# 9            9            Lexi Luna
# 10          10         Emily Willis
# 11          11          Brandi Love
# 12          12            Lena Paul
# 13          13         Autumn Falls
# 14          14         Natasha Nice
# 15          15           Cory Chase
# 16          16  Jordi El Nino Polla
# 17          17            Lexi Lore
# 18          18      Adriana Chechik
# 19          19        Rae Lil Black
# 20          20          Kendra Lust
# 21          21     Anastasia Knight
# 22          22           Skylar Vox
# 23          23       Nicole Aniston
# 24          24              Sky Bri
# ...

# %%
d =pd.read_csv(r"C://Users//KOIN//Downloads//abc.csv")

# %%
d
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
d.head()
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65

# %%
d.info
# Out:
# <bound method DataFrame.info of   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23>

# %%
d.columns
# Out:
# Index(['student', 'language', 'science', 'maths', 'history'], dtype='object')

# %%
d.tail(5)
# Out:
#   student  language  science  maths  history
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23
